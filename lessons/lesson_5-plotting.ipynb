# %%
import numpy as np
import math
import matplotlib.pyplot as plt # plotting library

# %%
x = np.arange(1,10)
y = np.arange(1,10)
plt.plot(x, y, label="line")
plt.title("plot")
plt.xlabel("x")
plt.ylabel("y")
plt.legend(loc="upper left")

# book shows plt.show()
# this is not needed in Jupyter books
# but if you were in a .py script, you would need it to see

# %%
x
# Out:
# array([ 0.        ,  0.39269908,  0.78539816,  1.17809725,  1.57079633,
#         1.96349541,  2.35619449,  2.74889357,  3.14159265,  3.53429174,
#         3.92699082,  4.3196899 ,  4.71238898,  5.10508806,  5.49778714,
#         5.89048623,  6.28318531,  6.67588439,  7.06858347,  7.46128255,
#         7.85398163,  8.24668072,  8.6393798 ,  9.03207888,  9.42477796,
#         9.81747704, 10.21017612, 10.60287521, 10.99557429, 11.38827337,
#        11.78097245, 12.17367153, 12.56637061])

# %%
x = np.linspace(0, 4.0 * np.pi, 1000)
y = np.sin(x)
plt.plot(x, y)

# %% [markdown]
# 8.11.1-2
