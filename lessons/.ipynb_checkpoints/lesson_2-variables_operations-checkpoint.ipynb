# %%
# Recall

# pulling in a function and defining how to call it
import numpy as np

# defining a variable
x = 3

# defining another variable and performing an operation
y = x + 3

# using a function
np.sqrt(4)
# Out:
# np.float64(2.0)

# %% [markdown]
# # Class Activity
#
# 1. define two variables that are equal to 12 and 8
# 2. add them
# 3. subtract them
# 4. take the square root of each of them
# 5. save their difference as a new variable and take the square root of that
# 6. take the exponential of number 5 (e^x) (Function call can be found in Table 2.3)
#
# # Lab Problems
# 1. 2.10.3
# 2. 2.10.1
# 3. 2.10.2
