# %%
import numpy as np
import math
import matplotlib.pyplot as plt # plotting library

# %%
x = np.arange(1,10)
y = np.arange(1,10)
plt.plot(x, y, color="gray", label="line")
# plt.title("plot")
# plt.xlabel("x")
# plt.ylabel("y")
# plt.legend(loc="upper left")

# book shows plt.show()
# this is not needed in Jupyter books
# but if you were in a .py script, you would need it to see
# Out:
# Text(0.5, 1.0, 'plot')

# %%
x = np.linspace(0, 4.0 * np.pi, 33)
y = np.sin(x)
plt.plot(x, y)

# %% [markdown]
# 8.11.1-2
