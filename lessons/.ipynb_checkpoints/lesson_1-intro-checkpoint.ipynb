# %% [markdown]
# # This is a Header
# ## This is a smaller header
# ### This is the next level
#
# The # is used to make headers in a normal or "markdown" text box
#
# This is normal text
#
# _This is italicized text_
#
# __this is bolded text__
#
# This is not a code block -- note the left side
#
# Other keybindings to know:
# - a: makes a box (a)bove
# - b: makes a box (b)elow
# - x: deletes a box
# - m: makes box (m)arkdown (text environment)
# - y: makes box coding environment p(y)thon
# - ctrl+enter: "runs" the box
# - esc: exits out of the box without running it
# - enter: enters the box
# - "edit" row above also has "undo" if you delete cells or delete text

# %% [markdown]
# ##### The total distance $x$ traveled during a trip can be
# obtained by integrating the velocity $v(t)$ over the duration
# $T$ of the trip:
# \begin{equation}
# x = \int_0^T v(t)\,dt
# \end{equation}

# %%
# this is a code block
# number to the left indicates that you "ran" the block
# The "#" makes a comment which is text that is not "run" in your code
# comment to your self
# I am awesome (:

# %%
# this is another code block

# %%
x = 1.5923
type(x)
# Out:
# float

# %%
x = 1    # this is an int
y = 2.0  # this is a float

print(x)
x += 2    # add 2 to x
print(y)
print(x)

print(type(y))

a = "hello world!" # this is a string
print(a)
# Out:
# 1
# 2.0
# 3
# <class 'float'>
# hello world!

# %%
z = x + y
z
# Out:
# 5.0

# %%
z
# Out:
# 5.0

# %%
import numpy as np
np.cos(0)
# Out:
# np.float64(1.0)

# %%
import numpy as np # note the different coloring when in a code box

np.sqrt(4) # squareroot function
np.sin(0)  # sin function
np.cos(0)  # cos function
x**2       # this is to the power 3^2 = 9

x + y      # addition
x - y      # subtraction
# Out:
# 9

# %% [markdown]
# # Class Activity
#
# 1. define two variables that are equal to 5 and 6
# 2. add them
# 3. subtract them
# 4. take the square root of each of them
# 5. save their addition as a new variable and take the square root of that
# 6. take the exponential of number 5 (e^x) (Function call can be found in Table 2.3)
