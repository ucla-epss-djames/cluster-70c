# %% [markdown]
# # Control Flow & Looping Exercises
#
# **Cluster 70C — Spring 2026**
#
# These exercises build on what you already know: variables, lists, numpy arrays, and slicing. Each one introduces a new control-flow idea and gets a little more involved than the last. Work through them in order — and don't worry if you get stuck. Add a comment in your code where things broke down.
#
# Run the import cell below before starting.

# %%
import numpy as np

# %% [markdown]
# ---
# ## Exercise 1 — Water State Check
#
# **New idea:** `if` / `elif` / `else` branching.
#
# Given a planet's surface temperature in degrees Celsius, print whether water on the surface would be **solid**, **liquid**, or **gas** (assume Earth-like atmospheric pressure of 1 atm).
#
# Try changing `surface_temp` to `-40`, `15`, and `120` to make sure all three branches work.
#
# *Bonus question to think about: what assumption are we making here? What would change on Mars or Venus?*

# %%
surface_temp = 15  # degrees Celsius — change this and re-run

# Your code here:

# %% [markdown]
# ---
# ## Exercise 2 — Counting Habitable Worlds
#
# **New idea:** `for` loop with a counter variable.
#
# Below is a numpy array of equilibrium temperatures (in Kelvin) for a set of fictional exoplanets. Loop through the array and count how many fall in the **liquid-water range** (roughly 273 K to 373 K).
#
# Notice that `count` is set to 0 *before* the loop starts. Why does it need to be there and not inside the loop?

# %%
temps_K = np.array([180, 290, 305, 410, 250, 295, 600, 330])

count = 0

# Your code here:

print("Habitable-zone candidates:", count)

# %% [markdown]
# ---
# ## Exercise 3 — Extremophile Classifier
#
# **New idea:** looping with an index, combining conditions with `and`.
#
# Below are two parallel arrays — temperature (°C) and pH — for five different environments on Earth. Loop through them and classify each one:
#
# - Temp > 80 °C **and** pH < 3 → thermoacidophile territory
# - Temp > 80 °C only → thermophile-friendly
# - pH < 3 only → acidophile-friendly
# - Otherwise → nothing too extreme
#
# Hint: use `range(len(temps_C))` so you can pull values from both arrays at the same index.

# %%
temps_C = np.array([85, 25, 4, 95, 30])
pH      = np.array([6.5, 2.0, 7.0, 1.5, 7.2])

# Your code here:

# %% [markdown]
# ---
# ## Exercise 4 — Sorting Planets by Type
#
# **New idea:** keeping multiple counters at once, using `+=`.
#
# Below are radii and masses for seven planets, both in Earth units. Loop through and classify each planet by **radius**:
#
# - radius < 1.5 → rocky
# - 1.5 ≤ radius < 3 → super-Earth
# - radius ≥ 3 → gas giant
#
# Keep a running count of each type and print the totals at the end.
#
# *Note that `count += 1` is shorthand for `count = count + 1`.*
#
# *Question to consider: we're not using the mass array at all here. When might we need it?*

# %%
radii  = np.array([1.0, 0.5, 2.3, 11.2, 1.8, 0.9, 4.1])
masses = np.array([1.0, 0.1, 6.5, 318, 4.2, 0.8, 17])

rocky = 0
super_earth = 0
gas_giant = 0

# Your code here:


print("Rocky:", rocky)
print("Super-Earths:", super_earth)
print("Gas giants:", gas_giant)

# %% [markdown]
# ---
# ## Exercise 5 — Cooling Planet
#
# **New idea:** the `while` loop — repeat *until a condition becomes false*, instead of repeating a known number of times.
#
# A young planet starts at **1500 K** and loses **2% of its temperature every million years**. How many million years pass before the surface could support liquid water (T ≤ 373 K)?
#
# Fill in the loop below.
#
# **Watch out for infinite loops!** If your condition can never become false, the cell will run forever and you'll need to interrupt the kernel (Kernel → Interrupt). Things to ask yourself: *what changes inside the loop? does that change move the condition toward being false?*

# %%
temperature = 1500   # Kelvin
years_Myr = 0

# Your code here:


print(f"After {years_Myr} million years, T = {temperature:.1f} K")

# %% [markdown]
# ---
# ## Stretch Challenge (optional)
#
# Combine Exercises 2 and 5: start with a numpy array of 10 different starting temperatures (your choice). Simulate each planet cooling at 2% per Myr, and count how many reach habitable range (≤ 373 K) within 100 million years.
#
# Hint: you'll need a `for` loop *outside* and a `while` loop *inside*.

# %%
# Your code here
